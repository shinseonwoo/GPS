# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('D:/python/Netflix/netflix_originals_가공.csv')

# %%
df
# Out:
#                                  House of Cards    Political drama  Netflix  \
# 0                                 Hemlock Grove             Horror  Netflix
# 1                       Orange Is the New Black       Comedy-drama  Netflix
# 2                                    Marco Polo   Historical drama  Netflix
# 3                                     Bloodline           Thriller  Netflix
# 4                                     Daredevil  Superhero fiction  Netflix
# ..                                          ...                ...      ...
# 586                                Road to Roma          Making-of  Netflix
# 587                     Sitara: Let Girls Dream          Animation  Netflix
# 588                                 Sol Levante      Anime / Short  Netflix
# 589  Ben Platt: Live from Radio City Music Hall       Concert film  Netflix
# 590                           Catching Feelings    Romantic comedy  Netflix
#
# ...

# %%
df.describe()
# Out:
#           House of Cards Political drama  Netflix  01-Feb-13  \
# count                591             591      591        591
# unique               590             138        6        341
# top     Awaiting release   Documentaries  Netflix  10-Aug-18
# freq                   2             135      585          8
#
#        6 seasons, 73 episodes       42?59 min.  Worldwide    Ended
# count                     169              591        591      169
# unique                     51              262          3        2
# top      1 season, 8 episodes  1 hour, 40 min.  Worldwide  Ended\n
# freq                       31               17        585       95

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 591 entries, 0 to 590
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   House of Cards          591 non-null    object
#  1   Political drama         591 non-null    object
#  2   Netflix                 591 non-null    object
#  3   01-Feb-13               591 non-null    object
#  4   6 seasons, 73 episodes  169 non-null    object
#  5   42?59 min.              591 non-null    object
#  6   Worldwide               591 non-null    object
#  7   Ended                   169 non-null    object
# dtypes: object(8)
# memory usage: 37.1+ KB
