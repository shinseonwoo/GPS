# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_excel('netflix_original_종합.xlsx')

# %%
df
# Out:
#      Unnamed: 0                                       Title             Genre  \
# 0             0                              House of Cards   Political drama
# 1             1                               Hemlock Grove            Horror
# 2             2                     Orange Is the New Black      Comedy-drama
# 3             3                                  Marco Polo  Historical drama
# 4             4                                   Bloodline          Thriller
# ..          ...                                         ...               ...
# 584         584                                Road to Roma         Making-of
# 585         585                     Sitara: Let Girls Dream         Animation
# 586         586                                 Sol Levante     Anime / Short
# 587         587  Ben Platt: Live from Radio City Music Hall      Concert film
# 588         588                           Catching Feelings   Romantic comedy
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 589 entries, 0 to 588
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 589 non-null    int64
#  1   Title                      589 non-null    object
#  2   Genre                      589 non-null    object
#  3   Original Network           589 non-null    object
#  4   Premiere                   589 non-null    object
#  5   Seasons                    170 non-null    object
#  6   Length                     589 non-null    object
#  7   Netflix Exclusive Regions  589 non-null    object
#  8   Status                     170 non-null    object
#  9   ratings                    589 non-null    float64
#  10  voters                     589 non-null    object
#  11  director                   511 non-null    object
#  12  Stars                      384 non-null    object
# ...

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 589 entries, 0 to 588
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Title                      589 non-null    object
#  1   Genre                      589 non-null    object
#  2   Original Network           589 non-null    object
#  3   Premiere                   589 non-null    object
#  4   Seasons                    170 non-null    object
#  5   Length                     589 non-null    object
#  6   Netflix Exclusive Regions  589 non-null    object
#  7   Status                     170 non-null    object
#  8   ratings                    589 non-null    float64
#  9   voters                     589 non-null    object
#  10  director                   511 non-null    object
#  11  Stars                      384 non-null    object
#  12  All rating                 571 non-null    float64
# ...

# %%
excel_name='netflix_original_종합.xlsx'

# %%
df.to_excel(excel_name,encoding='utf-8')

# %%
df_1=df[df['ratings']!=df['All rating']]

# %%
df['All rating']
# Out:
# 0      8.7
# 1      7.1
# 2      8.1
# 3      8.0
# 4      8.0
#       ...
# 584    7.7
# 585    7.3
# 586    6.3
# 587    8.5
# 588    5.7
# Name: All rating, Length: 589, dtype: float64

# %%
df_1
# Out:
#                                                 Title                  Genre  \
# 18                               The Ponysitters Club                  Drama
# 19                                      The Innocents   Supernatural fiction
# 21                                             Shadow               Thriller
# 28                                    October Faction                 Horror
# 29                                        Richie Rich                 Sitcom
# ..                                                ...                    ...
# 577  American Factory: A Conversation with the Obamas  Aftershow / Interview
# 579       The Road to El Camino: A Breaking Bad Movie              Making-of
# 582               John Mulaney & the Sack Lunch Bunch           Variety show
# 586                                       Sol Levante          Anime / Short
# 588                                 Catching Feelings        Romantic comedy
#
# ...

# %%
excel_name='netflix_original_다른것.xlsx'

# %%
df_1.to_excel(excel_name,encoding='utf-8')
